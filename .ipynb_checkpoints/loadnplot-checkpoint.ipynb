# %% [markdown]
# # Facebook Stock👀
# > ## **They're watching you!**

# %% [markdown]
# ## Import modules

# %%
import quandl as ql
import plotly as py
import plotly.graph_objs as go
import pandas as pd
from txtanalysis import *
# import numpy as np
from keras.models import Sequential
from keras.layers import LSTM,Dense
from sklearn.preprocessing import MinMaxScaler
#import matplotlib.pyplot as plot
#import tensorflow as tf
scaler = MinMaxScaler()
# Out:
# D:\Tools\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning:
#
# Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#
# Using TensorFlow backend.

# %% [markdown]
# Plotly and Quandl config

# %%
py.offline.init_notebook_mode(connected=True)
ql.ApiConfig.api_key = "b6y7-mew_t8z5yGJijFv"
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# ## Retriving, Slicing and Dicing

# %% [markdown]
# Use to fetch data from quandl

# %%
# data = ql.get("WIKI/fb")
# data.to_csv("Facebook", encoding='utf-8')

# %%
df = pd.read_csv("Facebook")[['Date','Open','Close','High','Low']]
train_limit = int(df.shape[0]*0.8)
train_data = df[:train_limit]
df[:5]
# Out:
#          Date   Open    Close   High    Low
# 0  2012-05-18  42.05  38.2318  45.00  38.00
# 1  2012-05-21  36.53  34.0300  36.66  33.00
# 2  2012-05-22  32.61  31.0000  33.59  30.94
# 3  2012-05-23  31.37  32.0000  32.50  31.36
# 4  2012-05-24  32.95  33.0300  33.21  31.77

# %% [markdown]
# ## Plotting as a TimeSeries

# %%
trace_high = go.Scatter(
    x=df['Date'],
    y=df['High'],
    name = "High",
#     line = dict(color = '#17BECF'),
    opacity = 0.9)

trace_low = go.Scatter(
    x=df['Date'],
    y=df['Low'],
    name = "Low",
#     line = dict(color = '#7F7F7F'),
    opacity = 0.8)

trace_open = go.Scatter(
    x=df['Date'],
    y=df['Open'],
    name = "Open",
#     line = dict(color = '#17BECF'),
    opacity = 0.9)

trace_close = go.Scatter(
    x=df['Date'],
    y=df['Close'],
    name = "Close",
#     line = dict(color = '#7F7F7F'),
    opacity = 0.8)

plot_data = [ trace_high, trace_low, trace_open, trace_close]

layout = go.Layout(
    title='Facebook',
    xaxis=dict(
        title='Date',
        titlefont=dict(
            family='Courier New, monospace',
            size=18,
            color='#7f7f7f'
        )
    ),
    yaxis=dict(
        title='Prices',
        titlefont=dict(
            family='Courier New, monospace',
            size=18,
            color='#7f7f7f'
        )
    )
)

fig = dict(data=plot_data, layout=layout)
py.offline.iplot(fig, filename = "Facebook Plot")
# Out:
# <div id="23e0b39f-37b0-42ef-aca2-7b75ed68a165" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("23e0b39f-37b0-42ef-aca2-7b75ed68a165", [{"type": "scatter", "x": ["2012-05-18", "2012-05-21", "2012-05-22", "2012-05-23", "2012-05-24", "2012-05-25", "2012-05-29", "2012-05-30", "2012-05-31", "2012-06-01", "2012-06-04", "2012-06-05", "2012-06-06", "2012-06-07", "2012-06-08", "2012-06-11", "2012-06-12", "2012-06-13", "2012-06-14", "2012-06-15", "2012-06-18", "2012-06-19", "2012-06-20", "2012-06-21", "2012-06-22", "2012-06-25", "2012-06-26", "2012-06-27", "2012-06-28", "2012-06-29", "2012-07-02", "2012-07-03", "2012-07-05", "2012-07-06", "2012-07-09", "2012-07-10", "2012-07-11", "2012-07-12", "2012-07-13", "2012-07-16", "2012-07-17", "2012-07-18", "2012-07-19", "2012-07-20", "2012-07-23", "2012-07-24", "201
# ...

# %%
tw = TweetSentiments()
df['Sentiments'] = 0.0
for i in range( train_limit):
    df[['Sentiments']] = df[['Date']].apply(lambda x: tw.get_input( '@facebook', x[i]))
df[:5]

# %% [markdown]
# # Some data magic!!

# %% [markdown]
# ## Scaling
# Warning! DataFrames will be changed after this...

# %%
df[['Open','Close','High','Low']] = scaler.fit_transform(df[['Open','Close','High','Low']])
df = df.drop( ['Date'], axis = 1)
train_data = df[:train_limit]
test_data = df[train_limit:]
train_data[:5]
# df[['Open','Close','High','Low']] = scaler.inverse_transform(df[['Open','Close','High','Low']])
# df

# %% [markdown]
# ## LSTM
